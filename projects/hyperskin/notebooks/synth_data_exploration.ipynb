# %%
#read .mat files
import numpy as np
import os 
import torch
from scipy.io import savemat, loadmat
import matplotlib.pyplot as plt

# %%
path = '/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/data/hsi_dermoscopy_synth_vae/images/MMCube/sample_000053.mat'
path2 = '/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/data/hsi_dermoscopy_croppedv2_256_with_masks/images/MMCube/1_crop00.mat'
path3 = '/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/generated_samples/sample_000000.mat'
path4 = '/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/generated_samples-fastgan/sample_0001.mat'

# %%
mat_data = loadmat(path4)
# loadmat returns dict, get the last item's value (the actual data)
image = mat_data.popitem()[-1]
image.shape
# Out:
# (256, 256, 16)

# %%
plt.imshow(image[:, :, 8], cmap='gray')
plt.show()

# %%
data = torch.load('/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/data/hsi_dermoscopy_synth_vae/0_10000.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = torch.load('/mnt/datassd/genai/dgm-2025.2/projects/hyperskin/data/hsi_dermoscopy_synth_vae/0_10000.pt')
#
# File /mnt/datassd/icasp/miniconda3/envs/genai/lib/python3.10/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# ...
